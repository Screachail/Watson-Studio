# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kacper Szafraniec - Junior Data Scientist

# %% [markdown]
# *I am interested in a Data Science because I am eager to contribute to the world development based on the information flying everywhere around us. Data can be considered as one of the physics elements of which our world is constructed. Understanding this power is something that truly fascinates me!

# %% [markdown]
# ### This is a simple code just to show you that I can differentiate between markdown and code sections

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4      Eve   29      Phoenix

# %%
# Perform a Transformation
average_age = df['Age'].mean()
df['Above_Average_Age'] = df['Age'] > average_age
print(df)
# Out:
#       Name  Age         City  Above_Average_Age
# 0    Alice   24     New York              False
# 1      Bob   27  Los Angeles               True
# 2  Charlie   22      Chicago              False
# 3    David   32      Houston               True
# 4      Eve   29      Phoenix               True

# %%
# Plot the Data

plt.figure(figsize=(8, 5))
plt.bar(df['Name'], df['Age'], color='skyblue')
plt.axhline(y=average_age, color='r', linestyle='--', label=f'Average Age: {average_age:.2f}')
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Age of Individuals')
plt.legend()
plt.show()
